# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load nn.py

# %%
with open('nn.py', 'r') as file:
    code = file.read()

# %%
print(code)
# Out:
# # -*- coding: utf-8 -*-
# """nn.ipynb
#
# Automatically generated by Colaboratory.
#
# Original file is located at
#     https://colab.research.google.com/drive/1LealFOZf0ukDp7e0dJ5PrtFUeVRgNYtd
# """
#
# """
# The main code for the feedforward networks assignment.
# See README.md for details.
# """
# from typing import Tuple, Dict
#
# import tensorflow
#
#
# def create_auto_mpg_deep_and_wide_networks(
#         n_inputs: int, n_outputs: int) -> Tuple[tensorflow.keras.models.Model,
#                                                 tensorflow.keras.models.Model]:
#     """Creates one deep neural network and one wide neural network.
#     The networks should have the same (or very close to the same) number of
#     parameters and the same activation functions.
#
#     The neural networks will be asked to predict the number of miles per gallon
#     that different cars get. They will be trained and tested on the Auto MPG
#     dataset from:
# ...

# %%
# %load test_nn.py

# %%
# !pytest
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.10.12, pytest-7.4.4, pluggy-1.3.0
# rootdir: /content
# plugins: anyio-3.7.1
# collected 3 items
#
# test_nn.py
# 7.5 RMSE for baseline on Auto MPG
# 7.5 RMSE for deep on Auto MPG
# 5.7 RMSE for wide on Auto MPG
# .
# 18.2% accuracy for baseline on UCI-HAR
# 93.3% accuracy for dropout on UCI-HAR
# 92.6% accuracy for no dropout on UCI-HAR
# .
# 25.2% accuracy for baseline on census income
# 76.7% accuracy for early on census income
# 77.5% accuracy for late on census income
# .                                                                               [100%]
#
# ======================================== 3 passed in 53.55s ========================================
